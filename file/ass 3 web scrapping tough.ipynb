# %% [markdown]
# 1. Write a python program which searches all the product under a particular product from www.amazon.in. The
# product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for
# guitars.
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search
# results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then
# scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
! pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
import re
#from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException

# %% [markdown]
# #Write a python program which searches all the product under a particular product from www.amazon.in. The
# product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for
# guitars.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in')

# %%
search=driver.find_element(By.XPATH,'//div[@class="nav-search-field "]/input')
search.send_keys(input('enter your item :' ))
# Out:
# enter your item :guitar

# %%
search=driver.find_element(By.XPATH,'//*[@id="nav-search-submit-text"]')# i have use id for submit/click on search 
search.click()

# %%
product_url=[]
start=0
end=3
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()
    time.sleep(3)

# %%
len(product_url)
# Out:
# 184

# %%
Brand=[]
Name_Product=[]
Price=[]
Return=[]
exp_del=[]
Availability=[]
Product_URL=[]




for url in product_url:
    driver.get(url)
    time.sleep(2)

    try:
        brand=driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span') #check this xpath Vvv imp
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')
        
    try:
        n=driver.find_element(By.XPATH,'//span[@class="a-size-large product-title-word-break"]') #check this xpath Vvv imp
        Name_Product.append(n.text)
    except NoSuchElementException:
        Name_Product.append('-')
        
    try:
        p=driver.find_element(By.XPATH,'//span[@class="a-price-whole"]') #check this xpath Vvv imp
        Price.append(p.text)
    except NoSuchElementException:
        Price.append('-')
        
    try:
        r=driver.find_element(By.XPATH,'//div[@class="a-section a-spacing-none"]/img') #check this xpath Vvv imp
        Return.append(r.text)
    except NoSuchElementException:
        Return.append('-')
        
    try:
        a=driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]') #check this xpath Vvv imp
        Availability.append(a.text)
    except NoSuchElementException:
        Availability.append('-')

# %%
print(len(Brand),
len(Name_Product),
len(Price),
len(Return),
len(Availability))
# Out:
# 184 184 184 184 184

# %%
guitar = pd.DataFrame({})
guitar['Brand Name'] = Brand
guitar['Name of the Product'] = Name_Product
guitar['Price'] = Price
guitar['Return/Exchange'] = Return
guitar['Availability'] = Availability
guitar
# Out:
#        Brand Name                                Name of the Product   Price  \
# 0         Kadence  Kadence rosewood Guitar Frontier Series, Elect...   5,499
# 1          Fender  Fender FA125CE Electric Acoustic Guitar Cutawa...  22,999
# 2          Henrix  Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...   3,199
# 3          Fender  Fender SA105CE Electric Acoustic Guitar With M...  14,939
# 4          JUAREZ  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   1,999
# ..            ...                                                ...     ...
# 179  allmusicmart  “ALL WOODEN” 38” INCH "BOLT" Guitar Combo Pack...   2,550
# 180  allmusicmart  “ALL WOODEN” 38” INCH "BOLT" Guitar Combo Pack...   2,550
# 181  PS Signature  PS Signature 39 Inch Pine Wood Acoustic Guitar...   3,599
# 182       MUSTANG  Mustang 46 PCS Guitar Strings Changing Kit Gui...     895
# 183       natural  SG Musical Harmonium- 3 1/4 Octave, Double Bel...   5,990
#
#     Return/Exchange Availability
# ...

# %%
guitar.to_csv("Guitar.csv")

# %% [markdown]
# # Solution 1 and 2 End here ---------------------all set

# %% [markdown]
# # Ques 3Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.google.co.in/')

# %%
images=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/div/div/div/div[1]/div/div[2]/a')
images.click()

# %%
search=driver.find_element(By.XPATH,'//*[@id="APjFqb"]')
search.send_keys('cake')

# %%
#note for other 2 liabrary to be imported
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait

# %%
for _ in range(20):
    driver.execute_script('window.scrollBy(0,500)')

images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i>10:
        print("downloading {0} of {1} images" . format(i,10))
        response=requests.get(img_urls[i])
        file=open(r"C:\Users\91903\Desktop\images" + str(i) + ".jpg" , "wb")
        file.write(response.content)
# Out:
# downloading 11 of 10 images
# downloading 12 of 10 images
# downloading 13 of 10 images
# downloading 14 of 10 images
# downloading 15 of 10 images
# downloading 16 of 10 images
# downloading 17 of 10 images
# downloading 18 of 10 images
# downloading 19 of 10 images
# downloading 20 of 10 images
# downloading 21 of 10 images
# downloading 22 of 10 images
# downloading 23 of 10 images
# downloading 24 of 10 images
# downloading 25 of 10 images
# downloading 26 of 10 images
# downloading 27 of 10 images
# downloading 28 of 10 images
# downloading 29 of 10 images
# downloading 30 of 10 images
# downloading 31 of 10 images
# downloading 32 of 10 images
# downloading 33 of 10 images
# downloading 34 of 10 images
# downloading 35 of 10 images
# downloading 36 of 10 images
# downloading 37 of 10 images
# downloading 38 of 10 images
# downloading 39 of 10 images
# downloading 40 of 10 images
# downloading 41 of 10 images
# downloading 42 of 10 images
# downloading 43 of 10 images
# ...

# %%
#fruits
for _ in range(20):
    driver.execute_script('window.scrollBy(0,500)')

images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i>10:
        print("downloading {0} of {1} images" . format(i,10))
        response=requests.get(img_urls[i])
        file=open(r"C:\Users\91903\Desktop\images" + str(i) + ".jpg" , "wb")
        file.write(response.content)
# Out:
# downloading 11 of 10 images
# downloading 12 of 10 images
# downloading 13 of 10 images
# downloading 14 of 10 images
# downloading 15 of 10 images
# downloading 16 of 10 images
# downloading 17 of 10 images
# downloading 18 of 10 images
# downloading 19 of 10 images
# downloading 20 of 10 images
# downloading 21 of 10 images
# downloading 22 of 10 images
# downloading 23 of 10 images
# downloading 24 of 10 images
# downloading 25 of 10 images
# downloading 26 of 10 images
# downloading 27 of 10 images
# downloading 28 of 10 images
# downloading 29 of 10 images
# downloading 30 of 10 images
# downloading 31 of 10 images
# downloading 32 of 10 images
# downloading 33 of 10 images
# downloading 34 of 10 images
# downloading 35 of 10 images
# downloading 36 of 10 images
# downloading 37 of 10 images
# downloading 38 of 10 images
# downloading 39 of 10 images
# downloading 40 of 10 images
# downloading 41 of 10 images
# downloading 42 of 10 images
# downloading 43 of 10 images

# %%
#cars
for _ in range(20):
    driver.execute_script('window.scrollBy(0,500)')

images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i>10:
        print("downloading {0} of {1} images" . format(i,10))
        response=requests.get(img_urls[i])
        file=open(r"C:\Users\91903\Desktop\images" + str(i) + ".jpg" , "wb")
        file.write(response.content)
# Out:
# downloading 11 of 10 images
# downloading 12 of 10 images
# downloading 13 of 10 images
# downloading 14 of 10 images
# downloading 15 of 10 images
# downloading 16 of 10 images
# downloading 17 of 10 images
# downloading 18 of 10 images
# downloading 19 of 10 images
# downloading 20 of 10 images
# downloading 21 of 10 images
# downloading 22 of 10 images
# downloading 23 of 10 images
# downloading 24 of 10 images
# downloading 25 of 10 images
# downloading 26 of 10 images

# %% [markdown]
# #ans 3 ends here

# %%
# Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com 
# and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand 
# Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,  
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the 
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
search.send_keys('one plusnord')

# %%
click=driver.find_element(By.XPATH,'//button[@class="_2iLD__"]')
click.click()

# %%
page_url=[]
start=0
end=1
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
    for i in url:
        page_url.append(i.get_attribute('href'))
    time.sleep(3)

# %%
len(page_url)
# Out:
# 24

# %%
Brand= []
Phone_name= []
Colour= []
RAM= []
rom= []
Primary_Camera = []
Secondary_Camera= []
# Smartphones['Display Size'] = []
# Smartphones['Battery Capacity'] = []
# Smartphones['Price'] = []
# Smartphones['URL'] = []



for url in page_url:
    driver.get(url)
    time.sleep(2)

    
    try:
        read_more = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
    

#Phonename        
    try:
        n=driver.find_element(By.XPATH,'//table[@class="_14cfVK"][1]/tbody/tr[3]/td[2]') #check this xpath Vvv imp
        Phone_name.append(n.text)
    except NoSuchElementException:
        Phone_name.append('-')
 #colour       
    try:
        p=driver.find_element(By.XPATH,'//*[@id="Color"]') #check this xpath Vvv imp
        Colour.append(p.text)
    except NoSuchElementException:
        Colour.append('-')
#ram (in this we have 4 classes so mentioned[4] 4th table and tr[2]means 2nd tr till we reach our class same we done with rom)    
    try:
        r=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]') #ccheck table 4 new learning
        RAM.append(r.text)
    except NoSuchElementException:
        RAM.append('-')
#rom   --same as ram table 4 but rome present in under tr1 >td 2 i.e 1 row column 2   
    try:
        a=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]') 
        rom.append(a.text)
    except NoSuchElementException:
        rom.append('-')
        
#Primary Camera    --table 5 for primary camera 
    try:
        a=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[1]/td[2]') 
        Primary_Camera.append(a.text)
    except NoSuchElementException:
        Primary_Camera.append('-')
  #Secondary Camera  
    try:
        a=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]') 
        Secondary_Camera.append(a.text)
    except NoSuchElementException:
        Secondary_Camera.append('-')

# %%
    
# #Brand Name
#     try:
#         brand_tags = driver.find_elements(By.XPATH,"//span[@class='B_NuCI']")
#         Smartphones['Brand'].append(brand_tags.split()[0])
#     except NoSuchElementException:
#         Smartphones['Brand'].append('-')

# %%
df=pd.DataFrame({'Phone_name':Phone_name,'Colour':Colour,'RAM':RAM,'rom':rom,'Primary_Camera':Primary_Camera,'Secondary_Camera':Secondary_Camera})
df
# Out:
#            Phone_name Colour    RAM     rom     Primary_Camera  \
# 0   Nord CE 2 Lite 5G  Color   6 GB  128 GB   64MP Rear Camera
# 1   Nord CE 3 Lite 5G  Color   8 GB  256 GB  108MP Rear Camera
# 2   Nord CE 3 Lite 5G  Color   8 GB  256 GB  108MP Rear Camera
# 3   Nord CE 3 Lite 5G  Color   8 GB  128 GB  108MP Rear Camera
# 4   Nord CE 3 Lite 5G  Color   8 GB  128 GB  108MP Rear Camera
# 5   Nord CE 2 Lite 5G  Color   6 GB  128 GB   64MP Rear Camera
# 6   Nord CE 3 Lite 5G  Color   8 GB  256 GB  108MP Rear Camera
# 7   Nord CE 3 Lite 5G  Color   8 GB  256 GB  108MP Rear Camera
# 8   Nord CE 3 Lite 5G      -   8 GB  128 GB  108MP Rear Camera
# 9   Nord CE 3 Lite 5G      -   8 GB  128 GB  108MP Rear Camera
# 10        Nord CE3 5G  Color  12 GB  256 GB   50MP Rear Camera
# 11        Nord CE3 5G  Color  12 GB  256 GB   50MP Rear Camera
# 12        Nord CE3 5G  Color   8 GB  128 GB   50MP Rear Camera
# 13        Nord CE3 5G  Color   8 GB  128 GB   50MP Rear Camera
# ...

# %% [markdown]
# #ans 4 complete here(not some detais are missing like brand and dispaly)

# %% [markdown]
# #ques Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver=webdriver.Chrome()
driver.get('https://www.google.com/maps')
search=driver.find_element(By.XPATH,'//input[@class="searchboxinput xiQnY"]')
search.send_keys(input('enter your item :' ))
# Out:
# enter your item :punjab

# %%
click=driver.find_element(By.XPATH,'//div[@class="pzfvzf"]/button')
click.click()

# %%
try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.com/maps/place/Punjab/@31.0046072,72.7680189,7z/data=!3m1!4b1!4m6!3m5!1s0x391964aa569e7355:0x8fbd263103a38861!8m2!3d31.1471305!4d75.3412179!16zL20vMDc1X3Qy?entry=ttu
# Latitude = 31.0046072, Longitude = 72.7680189

# %% [markdown]
# #ans 5 Ends here

# %% [markdown]
# # qus 6 Write a program to scrap all the available details of best gaming laptops from digit.in.
